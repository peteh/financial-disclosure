# %%
import camelot
import tkinter
tables = camelot.read_pdf("data/2024/reports/20024305.pdf", flavor="stream")#, columns=['60, 100, 260,320,380, 440'],row_tol=15, pages="all")
tables[0].df
# Out:
#               0                                        1  \
# 0   Owner Asset
# 1
# 2            DC              CareCloud, Inc. (CCLD) [ST]
# 3                                     F S: New
# 4                S O: Kaden Everett Hern Trust
# 5                             D: sell to close
# 6            JT           Devon Energy Corporation (DVN)
# 7                                                   [ST]
# 8                                     F S: New
# 9
# 10                    D: Dividend Reinvestment
# 11           JT           Devon Energy Corporation (DVN)
# 12                                                  [ST]
# 13                                    F S: New
# 14                 S O: Hern Family Foundation
# 15                    D: Dividend Reinvestment
# 16           JT           Emerson Electric Company (EMR)
# 17                                                  [ST]
# 18                                    F S: New
# 19
# 20                    D: Dividend Reinvestment
# ...

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# /tmp/ipykernel_26226/2005142002.py:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   camelot.plot(tables[0], kind='contour').show()

# %%
camelot.plot(tables[0], kind='joint').show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 camelot.plot(tables[0], kind='joint').show()
#
# File ~/Programming/financial-disclosure/.venv/lib/python3.11/site-packages/camelot/plotting.py:39, in PlotMethods.__call__(self, table, kind, filename)
#      37     raise NotImplementedError(f"Lattice flavor does not support kind='{kind}'")
#      38 elif table.flavor == "stream" and kind in ["joint", "line"]:
# ---> 39     raise NotImplementedError(f"Stream flavor does not support kind='{kind}'")
#      41 plot_method = getattr(self, kind)
#      42 fig = plot_method(table)
#
# NotImplementedError: Stream flavor does not support kind='joint'

# %%
camelot.plot(tables[0], kind='line').show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 camelot.plot(tables[0], kind='line').show()
#
# File ~/Programming/financial-disclosure/.venv/lib/python3.11/site-packages/camelot/plotting.py:39, in PlotMethods.__call__(self, table, kind, filename)
#      37     raise NotImplementedError(f"Lattice flavor does not support kind='{kind}'")
#      38 elif table.flavor == "stream" and kind in ["joint", "line"]:
# ---> 39     raise NotImplementedError(f"Stream flavor does not support kind='{kind}'")
#      41 plot_method = getattr(self, kind)
#      42 fig = plot_method(table)
#
# NotImplementedError: Stream flavor does not support kind='line'
